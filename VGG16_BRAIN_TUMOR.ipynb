# %%
import os
import random
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import cv2
import imutils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import VGG16

# Clone the repo if not already done
repo_url = "https://github.com/nazianafis/Brain-MRI-Classification.git"
clone_dir = "./Brain-MRI-Classification"
if not os.path.exists(clone_dir):
    os.system(f"git clone {repo_url}")
else:
    print(f"Repository already cloned at {clone_dir}")

# Dataset paths
original_train_dir = os.path.join(clone_dir, "Brain-MRI", "Training")
original_test_dir = os.path.join(clone_dir, "Brain-MRI", "Testing")

if not os.path.exists(original_train_dir) or not os.path.exists(original_test_dir):
    raise FileNotFoundError("Training or Testing directories missing in cloned repo.")

classes = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

# Prepare folders for cropped images
base_train_dir = "./Crop-Brain-MRI"
base_test_dir = "./Test-Brain-MRI"
for base_dir in [base_train_dir, base_test_dir]:
    os.makedirs(base_dir, exist_ok=True)
    for cls in classes:
        os.makedirs(os.path.join(base_dir, cls), exist_ok=True)

def crop_image(image, plot=False):
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.GaussianBlur(img_gray, (5, 5), 0)
    _, img_thresh = cv2.threshold(img_gray, 45, 255, cv2.THRESH_BINARY)
    img_thresh = cv2.erode(img_thresh, None, iterations=2)
    img_thresh = cv2.dilate(img_thresh, None, iterations=2)
    contours = cv2.findContours(img_thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    if contours:
        c = max(contours, key=cv2.contourArea)
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])
        new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]
        if plot:
            plt.figure(figsize=(8,4))
            plt.subplot(1,2,1)
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.title("Original Image")
            plt.axis('off')
            plt.subplot(1,2,2)
            plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
            plt.title("Cropped Image")
            plt.axis('off')
            plt.show()
        return new_image
    else:
        return image

# Crop and resize to 224x224 for VGG16
def process_images(src_dir, dst_dir):
    for cls in classes:
        src_cls_dir = os.path.join(src_dir, cls)
        dst_cls_dir = os.path.join(dst_dir, cls)
        if not os.path.exists(src_cls_dir):
            print(f"Warning: Folder missing {src_cls_dir}, skipping.")
            continue
        for j, img_name in enumerate(tqdm(os.listdir(src_cls_dir), desc=f"Processing {dst_dir} {cls}")):
            img_path = os.path.join(src_cls_dir, img_name)
            img = cv2.imread(img_path)
            if img is not None:
                cropped = crop_image(img)
                resized = cv2.resize(cropped, (224, 224))
                cv2.imwrite(os.path.join(dst_cls_dir, f"{j}.jpg"), resized)

process_images(original_train_dir, base_train_dir)
process_images(original_test_dir, base_test_dir)

# Data augmentation and split
datagen = ImageDataGenerator(rotation_range=10,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.2)

train_generator = datagen.flow_from_directory(base_train_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training',
                                              shuffle=True)

valid_generator = datagen.flow_from_directory(base_train_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='validation',
                                              shuffle=True)

test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(base_test_dir,
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical',
                                                  shuffle=False)


# Build VGG16-based model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
output = Dense(len(classes), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

checkpoint = ModelCheckpoint('best_model_vgg16.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# Train
history = model.fit(train_generator,
                    validation_data=valid_generator,
                    epochs=30,
                    callbacks=[checkpoint, earlystop])

# Plot training history
epochs = range(1, len(history.history['accuracy']) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['accuracy'], 'go-', label='Train Accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'ro-', label='Validation Accuracy')
plt.plot(epochs, history.history['loss'], 'g^-', label='Train Loss')
plt.plot(epochs, history.history['val_loss'], 'r^-', label='Validation Loss')
plt.title('VGG16 Model Accuracy and Loss')
plt.xlabel('Epochs')
plt.ylabel('Value')
plt.legend()
plt.show()

# Visualize random predictions
class_labels = {v: k for k, v in train_generator.class_indices.items()}
image_paths = []
for cls in classes:
    cls_dir = os.path.join(base_test_dir, cls)
    if os.path.exists(cls_dir):
        image_paths.extend([os.path.join(cls_dir, f) for f in os.listdir(cls_dir) if f.endswith(('.jpg', '.png'))])
random_samples = random.sample(image_paths, min(len(image_paths), 10))

plt.figure(figsize=(20, 8))
for i, img_path in enumerate(random_samples):
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img_rgb, (224, 224))
    img_expanded = np.expand_dims(img_resized, axis=0) / 255.0

    preds = model.predict(img_expanded)
    pred_class = class_labels[np.argmax(preds)]

    plt.subplot(2, 5, i + 1)
    plt.imshow(img_rgb)
    plt.title(f"Predicted: {pred_class}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Processing ./Crop-Brain-MRI glioma_tumor: 100%|██████████| 926/926 [00:02<00:00, 313.65it/s]
# Processing ./Crop-Brain-MRI meningioma_tumor: 100%|██████████| 937/937 [00:03<00:00, 270.88it/s]
# Processing ./Crop-Brain-MRI no_tumor: 100%|██████████| 501/501 [00:01<00:00, 382.15it/s]
# Processing ./Crop-Brain-MRI pituitary_tumor: 100%|██████████| 901/901 [00:03<00:00, 285.59it/s]
# Processing ./Test-Brain-MRI glioma_tumor: 100%|██████████| 5/5 [00:00<00:00, 262.02it/s]
# Processing ./Test-Brain-MRI meningioma_tumor: 100%|██████████| 5/5 [00:00<00:00, 271.13it/s]
# Processing ./Test-Brain-MRI no_tumor: 100%|██████████| 5/5 [00:00<00:00, 508.45it/s]
# Processing ./Test-Brain-MRI pituitary_tumor: 100%|██████████| 5/5 [00:00<00:00, 198.60it/s]
# Found 2613 images belonging to 4 classes.
# Found 652 images belonging to 4 classes.
# Found 20 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 960ms/step - accuracy: 0.3026 - loss: 1.8776
# Epoch 1: val_accuracy improved from -inf to 0.40951, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 151s 1s/step - accuracy: 0.3028 - loss: 1.8727 - val_accuracy: 0.4095 - val_loss: 1.2728
# Epoch 2/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.3562 - loss: 1.3288
# Epoch 2: val_accuracy did not improve from 0.40951
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 682ms/step - accuracy: 0.3561 - loss: 1.3287 - val_accuracy: 0.3865 - val_loss: 1.3132
# Epoch 3/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.3407 - loss: 1.2983
# Epoch 3: val_accuracy improved from 0.40951 to 0.44479, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 682ms/step - accuracy: 0.3407 - loss: 1.2983 - val_accuracy: 0.4448 - val_loss: 1.3066
# Epoch 4/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.3952 - loss: 1.2693
# Epoch 4: val_accuracy improved from 0.44479 to 0.48313, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 679ms/step - accuracy: 0.3952 - loss: 1.2692 - val_accuracy: 0.4831 - val_loss: 1.0866
# Epoch 5/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - accuracy: 0.3973 - loss: 1.2675
# Epoch 5: val_accuracy did not improve from 0.48313
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.3972 - loss: 1.2676 - val_accuracy: 0.4433 - val_loss: 1.1817
# Epoch 6/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.4243 - loss: 1.1836
# Epoch 6: val_accuracy did not improve from 0.48313
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 676ms/step - accuracy: 0.4243 - loss: 1.1836 - val_accuracy: 0.2561 - val_loss: 1.3279
# Epoch 7/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.3664 - loss: 1.2962
# Epoch 7: val_accuracy improved from 0.48313 to 0.52914, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 678ms/step - accuracy: 0.3669 - loss: 1.2956 - val_accuracy: 0.5291 - val_loss: 1.0429
# Epoch 8/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.4461 - loss: 1.1341
# Epoch 8: val_accuracy improved from 0.52914 to 0.68252, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 688ms/step - accuracy: 0.4462 - loss: 1.1343 - val_accuracy: 0.6825 - val_loss: 0.9653
# Epoch 9/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.5702 - loss: 1.0349
# Epoch 9: val_accuracy improved from 0.68252 to 0.69785, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 698ms/step - accuracy: 0.5706 - loss: 1.0342 - val_accuracy: 0.6979 - val_loss: 0.7555
# Epoch 10/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.6890 - loss: 0.7923
# Epoch 10: val_accuracy improved from 0.69785 to 0.79448, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 685ms/step - accuracy: 0.6891 - loss: 0.7920 - val_accuracy: 0.7945 - val_loss: 0.5867
# Epoch 11/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.7399 - loss: 0.6870
# Epoch 11: val_accuracy did not improve from 0.79448
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 668ms/step - accuracy: 0.7396 - loss: 0.6875 - val_accuracy: 0.6043 - val_loss: 1.0175
# Epoch 12/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.7391 - loss: 0.6983
# Epoch 12: val_accuracy improved from 0.79448 to 0.79908, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 697ms/step - accuracy: 0.7392 - loss: 0.6980 - val_accuracy: 0.7991 - val_loss: 0.5886
# Epoch 13/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.7578 - loss: 0.6344
# Epoch 13: val_accuracy improved from 0.79908 to 0.84049, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 679ms/step - accuracy: 0.7579 - loss: 0.6340 - val_accuracy: 0.8405 - val_loss: 0.4640
# Epoch 14/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.8095 - loss: 0.5261
# Epoch 14: val_accuracy improved from 0.84049 to 0.85276, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 695ms/step - accuracy: 0.8095 - loss: 0.5261 - val_accuracy: 0.8528 - val_loss: 0.4133
# Epoch 15/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - accuracy: 0.7890 - loss: 0.5452
# Epoch 15: val_accuracy did not improve from 0.85276
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 672ms/step - accuracy: 0.7886 - loss: 0.5462 - val_accuracy: 0.8512 - val_loss: 0.4652
# Epoch 16/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.8322 - loss: 0.4585
# Epoch 16: val_accuracy improved from 0.85276 to 0.87883, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 684ms/step - accuracy: 0.8322 - loss: 0.4585 - val_accuracy: 0.8788 - val_loss: 0.3304
# Epoch 17/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - accuracy: 0.8670 - loss: 0.3882
# Epoch 17: val_accuracy improved from 0.87883 to 0.88650, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 677ms/step - accuracy: 0.8669 - loss: 0.3886 - val_accuracy: 0.8865 - val_loss: 0.3303
# Epoch 18/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - accuracy: 0.8832 - loss: 0.3412
# Epoch 18: val_accuracy improved from 0.88650 to 0.90951, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 680ms/step - accuracy: 0.8832 - loss: 0.3413 - val_accuracy: 0.9095 - val_loss: 0.3254
# Epoch 19/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - accuracy: 0.8934 - loss: 0.3090
# Epoch 19: val_accuracy did not improve from 0.90951
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 672ms/step - accuracy: 0.8935 - loss: 0.3091 - val_accuracy: 0.9080 - val_loss: 0.2919
# Epoch 20/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9050 - loss: 0.3088
# Epoch 20: val_accuracy did not improve from 0.90951
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 671ms/step - accuracy: 0.9051 - loss: 0.3087 - val_accuracy: 0.9095 - val_loss: 0.3413
# Epoch 21/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - accuracy: 0.9239 - loss: 0.2341
# Epoch 21: val_accuracy improved from 0.90951 to 0.91411, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 688ms/step - accuracy: 0.9239 - loss: 0.2342 - val_accuracy: 0.9141 - val_loss: 0.2624
# Epoch 22/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9319 - loss: 0.2242
# Epoch 22: val_accuracy did not improve from 0.91411
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 667ms/step - accuracy: 0.9319 - loss: 0.2243 - val_accuracy: 0.9049 - val_loss: 0.3160
# Epoch 23/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - accuracy: 0.9242 - loss: 0.2392
# Epoch 23: val_accuracy did not improve from 0.91411
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 680ms/step - accuracy: 0.9243 - loss: 0.2388 - val_accuracy: 0.9110 - val_loss: 0.2811
# Epoch 24/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.9652 - loss: 0.1249
# Epoch 24: val_accuracy improved from 0.91411 to 0.91871, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 675ms/step - accuracy: 0.9652 - loss: 0.1252 - val_accuracy: 0.9187 - val_loss: 0.2384
# Epoch 25/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.9531 - loss: 0.1442
# Epoch 25: val_accuracy improved from 0.91871 to 0.94018, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 690ms/step - accuracy: 0.9531 - loss: 0.1443 - val_accuracy: 0.9402 - val_loss: 0.1992
# Epoch 26/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.9510 - loss: 0.1311
# Epoch 26: val_accuracy did not improve from 0.94018
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 676ms/step - accuracy: 0.9510 - loss: 0.1313 - val_accuracy: 0.9218 - val_loss: 0.2286
# Epoch 27/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - accuracy: 0.9661 - loss: 0.1089
# Epoch 27: val_accuracy did not improve from 0.94018
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 56s 680ms/step - accuracy: 0.9660 - loss: 0.1090 - val_accuracy: 0.9064 - val_loss: 0.2496
# Epoch 28/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - accuracy: 0.9760 - loss: 0.0979
# Epoch 28: val_accuracy did not improve from 0.94018
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 673ms/step - accuracy: 0.9760 - loss: 0.0978 - val_accuracy: 0.9371 - val_loss: 0.2664
# Epoch 29/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - accuracy: 0.9721 - loss: 0.1043
# Epoch 29: val_accuracy did not improve from 0.94018
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 55s 677ms/step - accuracy: 0.9720 - loss: 0.1045 - val_accuracy: 0.9018 - val_loss: 0.3437
# Epoch 30/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - accuracy: 0.9528 - loss: 0.1782
# Epoch 30: val_accuracy improved from 0.94018 to 0.94939, saving model to best_model_vgg16.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 57s 684ms/step - accuracy: 0.9528 - loss: 0.1778 - val_accuracy: 0.9494 - val_loss: 0.2054
# Restoring model weights from the end of the best epoch: 25.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score


# Get true labels and predicted probabilities from test generator
test_steps = test_generator.samples // test_generator.batch_size
if test_generator.samples % test_generator.batch_size != 0:
    test_steps += 1

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator, steps=test_steps, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

# Accuracy
accuracy = accuracy_score(y_true, y_pred)

# F1 Score (macro and per class)
f1_macro = f1_score(y_true, y_pred, average='macro')
f1_per_class = f1_score(y_true, y_pred, average=None)

# Sensitivity (Recall)
recall_macro = recall_score(y_true, y_pred, average='macro')
recall_per_class = recall_score(y_true, y_pred, average=None)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Macro F1 Score:", f1_macro)
print("Per Class F1 Score:", f1_per_class)
print("Macro Sensitivity (Recall):", recall_macro)
print("Per Class Sensitivity (Recall):", recall_per_class)
print("Confusion Matrix:\n", cm)

# Optionally, display a classification report with precision, recall, f1 per class
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=classes))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# Accuracy: 0.9
# Macro F1 Score: 0.8920454545454546
# Per Class F1 Score: [0.75       0.90909091 0.90909091 1.        ]
# Macro Sensitivity (Recall): 0.9
# Per Class Sensitivity (Recall): [0.6 1.  1.  1. ]
# Confusion Matrix:
#  [[3 1 1 0]
#  [0 5 0 0]
#  [0 0 5 0]
#  [0 0 0 5]]
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.60      0.75         5
# meningioma_tumor       0.83      1.00      0.91         5
#         no_tumor       0.83      1.00      0.91         5
#  pituitary_tumor       1.00      1.00      1.00         5
#
#         accuracy                           0.90        20
#        macro avg       0.92      0.90      0.89        20
#     weighted avg       0.92      0.90      0.89        20

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Prepare a DataFrame for boxplot visualization
data = []
for i, cls in enumerate(classes):
    for j in range(len(y_true)):
        data.append({
            'True Class': classes[y_true[j]],
            'Predicted Class': cls,
            'Predicted Probability': y_pred_probs[j][i]
        })

df = pd.DataFrame(data)

plt.figure(figsize=(14, 8))
sns.boxplot(x='Predicted Class', y='Predicted Probability', hue='True Class', data=df, palette='tab10')
plt.title('Boxplot of Predicted Probabilities grouped by True Class')
plt.xticks(rotation=45)
plt.legend(title='True Class', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

def plot_classification_report_extended(y_true, y_pred, classes, figsize=(12, 6)):
    report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

    # Prepare rows for per-class, macro avg, weighted avg
    rows = classes + ['macro avg', 'weighted avg']
    metrics = ['precision', 'recall', 'f1-score']
    data = []
    for row in rows:
        row_data = [report[row][metric] if metric in report[row] else 0 for metric in metrics]
        data.append(row_data)

    df = pd.DataFrame(data, index=rows, columns=metrics)

    # Colors inspired by research standards (Tableau 10 palette samples)
    colors = ['#1f77b4',  # muted blue
              '#ff7f0e',  # safety orange
              '#2ca02c']  # cooked asparagus green

    ax = df.plot(kind='bar', figsize=figsize, color=colors)
    ax.set_title('Classification Report: Per Class, Macro & Weighted Avg')
    ax.set_ylabel('Score')
    ax.set_ylim(0, 1.05)
    ax.set_xlabel('Classes')
    ax.set_xticks(np.arange(len(rows)))
    ax.set_xticklabels(rows, rotation=45)
    ax.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

# Example usage:
plot_classification_report_extended(y_true, y_pred, classes)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report

def plot_classification_report(y_true, y_pred, classes, figsize=(8,6), cmap='Blues'):
    report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)
    # Remove accuracy and averages from the dict for plotting
    classes_metrics = {k: v for k, v in report.items() if k in classes}

    metrics = ['precision', 'recall', 'f1-score', 'support']
    values = np.array([[metrics_info[m] for m in metrics] for cls, metrics_info in classes_metrics.items()])
    # Plot support separately for better scale by normalizing or use separate axis if needed

    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(values[:, :-1], annot=True, fmt=".2f", cmap=cmap, cbar=True,
                yticklabels=classes, xticklabels=metrics[:-1], ax=ax)
    ax.set_title("Classification Report Metrics")
    plt.show()

# Use in your code after predictions like:
plot_classification_report(y_true, y_pred, classes)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)

# Rotate x-axis labels to 45 degrees with right alignment and anchored rotation
plt.xticks(rotation=45, ha='right', rotation_mode='anchor')

plt.title("Confusion Matrix")
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
import numpy as np

# Binarize the true labels for multiclass ROC (one-hot encoding)
y_true_bin = label_binarize(y_true, classes=range(len(classes)))
n_classes = y_true_bin.shape[1]

# Get prediction probabilities for each class
y_score = y_pred_probs

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green'])  # Use research paper style colors

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of class {classes[i]} (area = {roc_auc[i]:0.2f})')

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=3)

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal line for random guess
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curves')
plt.legend(loc="lower right")
plt.show()
