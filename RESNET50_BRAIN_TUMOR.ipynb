# %%
import os
import random
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
import cv2
import imutils
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import ResNet50  # TensorFlow doesn’t have ResNet18 by default, ResNet50 is common alternative


# Crop function same as before
def crop_image(image, plot=False):
    img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    img_gray = cv2.GaussianBlur(img_gray, (5, 5), 0)
    _, img_thresh = cv2.threshold(img_gray, 45, 255, cv2.THRESH_BINARY)
    img_thresh = cv2.erode(img_thresh, None, iterations=2)
    img_thresh = cv2.dilate(img_thresh, None, iterations=2)
    contours = cv2.findContours(img_thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    contours = imutils.grab_contours(contours)
    if contours:
        c = max(contours, key=cv2.contourArea)
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])
        new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]
        if plot:
            plt.figure(figsize=(8, 4))
            plt.subplot(1, 2, 1)
            plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
            plt.title("Original Image")
            plt.axis('off')
            plt.subplot(1, 2, 2)
            plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))
            plt.title("Cropped Image")
            plt.axis('off')
            plt.show()
        return new_image
    else:
        return image


def process_images(src_dir, dst_dir, classes):
    for cls in classes:
        src_cls_dir = os.path.join(src_dir, cls)
        dst_cls_dir = os.path.join(dst_dir, cls)
        os.makedirs(dst_cls_dir, exist_ok=True)
        if not os.path.exists(src_cls_dir):
            print(f"Warning: Missing {src_cls_dir}, skipping...")
            continue
        for j, img_name in enumerate(tqdm(os.listdir(src_cls_dir), desc=f"Processing {cls}")):
            img_path = os.path.join(src_cls_dir, img_name)
            img = cv2.imread(img_path)
            if img is not None:
                cropped = crop_image(img)
                resized = cv2.resize(cropped, (224, 224))  # ResNet input size
                cv2.imwrite(os.path.join(dst_cls_dir, f"{j}.jpg"), resized)


# Main setup
repo_url = "https://github.com/nazianafis/Brain-MRI-Classification.git"
clone_dir = "./Brain-MRI-Classification"
if not os.path.exists(clone_dir):
    os.system(f"git clone {repo_url}")

original_train_dir = os.path.join(clone_dir, "Brain-MRI", "Training")
original_test_dir = os.path.join(clone_dir, "Brain-MRI", "Testing")

if not os.path.exists(original_train_dir) or not os.path.exists(original_test_dir):
    raise FileNotFoundError("Training or Testing directories are missing.")

classes = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']

base_train_dir = "./Crop-Brain-MRI"
base_test_dir = "./Test-Brain-MRI"
for base_dir in [base_train_dir, base_test_dir]:
    os.makedirs(base_dir, exist_ok=True)

process_images(original_train_dir, base_train_dir, classes)
process_images(original_test_dir, base_test_dir, classes)

# Data generators
datagen = ImageDataGenerator(rotation_range=10,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             validation_split=0.2)

train_generator = datagen.flow_from_directory(base_train_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='training',
                                              shuffle=True)

valid_generator = datagen.flow_from_directory(base_train_dir,
                                              target_size=(224, 224),
                                              batch_size=32,
                                              class_mode='categorical',
                                              subset='validation',
                                              shuffle=True)

test_datagen = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory(base_test_dir,
                                                  target_size=(224, 224),
                                                  batch_size=32,
                                                  class_mode='categorical',
                                                  shuffle=False)


# Model based on ResNet50 as substitute for ResNet18
base_model = ResNet50(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
output = Dense(len(classes), activation='softmax')(x)
model = Model(inputs=base_model.input, outputs=output)

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

checkpoint = ModelCheckpoint('best_model_resnet50.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
earlystop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)

# Training
history = model.fit(train_generator,
                    validation_data=valid_generator,
                    epochs=30,
                    callbacks=[checkpoint, earlystop])

# Plot training history
epochs = range(1, len(history.history['accuracy']) + 1)
plt.figure(figsize=(10, 6))
plt.plot(epochs, history.history['accuracy'], 'go-', label='Train Accuracy')
plt.plot(epochs, history.history['val_accuracy'], 'ro-', label='Validation Accuracy')
plt.plot(epochs, history.history['loss'], 'g^-', label='Train Loss')
plt.plot(epochs, history.history['val_loss'], 'r^-', label='Validation Loss')
plt.title("ResNet50 Model Accuracy and Loss")
plt.xlabel("Epochs")
plt.ylabel("Value")
plt.legend()
plt.show()
# Out:
# Processing glioma_tumor: 100%|██████████| 926/926 [00:02<00:00, 366.55it/s]
# Processing meningioma_tumor: 100%|██████████| 937/937 [00:02<00:00, 386.02it/s]
# Processing no_tumor: 100%|██████████| 501/501 [00:01<00:00, 337.71it/s]
# Processing pituitary_tumor: 100%|██████████| 901/901 [00:03<00:00, 291.08it/s]
# Processing glioma_tumor: 100%|██████████| 5/5 [00:00<00:00, 326.80it/s]
# Processing meningioma_tumor: 100%|██████████| 5/5 [00:00<00:00, 316.21it/s]
# Processing no_tumor: 100%|██████████| 5/5 [00:00<00:00, 612.58it/s]
# Processing pituitary_tumor: 100%|██████████| 5/5 [00:00<00:00, 236.94it/s]
# Found 2613 images belonging to 4 classes.
# Found 652 images belonging to 4 classes.
# Found 20 images belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.6622 - loss: 0.8499
# Epoch 1: val_accuracy improved from -inf to 0.82055, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 141s 983ms/step - accuracy: 0.6636 - loss: 0.8466 - val_accuracy: 0.8206 - val_loss: 0.5221
# Epoch 2/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9304 - loss: 0.2219
# Epoch 2: val_accuracy improved from 0.82055 to 0.82362, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 46s 559ms/step - accuracy: 0.9304 - loss: 0.2216 - val_accuracy: 0.8236 - val_loss: 0.4868
# Epoch 3/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9562 - loss: 0.1253
# Epoch 3: val_accuracy did not improve from 0.82362
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 44s 536ms/step - accuracy: 0.9561 - loss: 0.1254 - val_accuracy: 0.7929 - val_loss: 0.6069
# Epoch 4/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9665 - loss: 0.0908
# Epoch 4: val_accuracy improved from 0.82362 to 0.86350, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 49s 593ms/step - accuracy: 0.9665 - loss: 0.0907 - val_accuracy: 0.8635 - val_loss: 0.3916
# Epoch 5/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9696 - loss: 0.0876
# Epoch 5: val_accuracy did not improve from 0.86350
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 551ms/step - accuracy: 0.9696 - loss: 0.0875 - val_accuracy: 0.8620 - val_loss: 0.3980
# Epoch 6/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9763 - loss: 0.0716
# Epoch 6: val_accuracy improved from 0.86350 to 0.91871, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 52s 630ms/step - accuracy: 0.9763 - loss: 0.0717 - val_accuracy: 0.9187 - val_loss: 0.2651
# Epoch 7/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9807 - loss: 0.0534
# Epoch 7: val_accuracy did not improve from 0.91871
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 46s 553ms/step - accuracy: 0.9806 - loss: 0.0536 - val_accuracy: 0.9064 - val_loss: 0.3150
# Epoch 8/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9875 - loss: 0.0316
# Epoch 8: val_accuracy did not improve from 0.91871
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 551ms/step - accuracy: 0.9875 - loss: 0.0317 - val_accuracy: 0.9156 - val_loss: 0.3175
# Epoch 9/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step - accuracy: 0.9864 - loss: 0.0401
# Epoch 9: val_accuracy improved from 0.91871 to 0.94785, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 52s 632ms/step - accuracy: 0.9864 - loss: 0.0401 - val_accuracy: 0.9479 - val_loss: 0.1449
# Epoch 10/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9933 - loss: 0.0282
# Epoch 10: val_accuracy did not improve from 0.94785
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 552ms/step - accuracy: 0.9932 - loss: 0.0284 - val_accuracy: 0.9310 - val_loss: 0.2353
# Epoch 11/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.9877 - loss: 0.0426
# Epoch 11: val_accuracy improved from 0.94785 to 0.95552, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 51s 618ms/step - accuracy: 0.9878 - loss: 0.0424 - val_accuracy: 0.9555 - val_loss: 0.1533
# Epoch 12/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9949 - loss: 0.0189
# Epoch 12: val_accuracy did not improve from 0.95552
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 552ms/step - accuracy: 0.9949 - loss: 0.0189 - val_accuracy: 0.9448 - val_loss: 0.2237
# Epoch 13/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9884 - loss: 0.0380
# Epoch 13: val_accuracy did not improve from 0.95552
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 546ms/step - accuracy: 0.9884 - loss: 0.0381 - val_accuracy: 0.9509 - val_loss: 0.2159
# Epoch 14/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.9909 - loss: 0.0339
# Epoch 14: val_accuracy improved from 0.95552 to 0.96319, saving model to best_model_resnet50.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 51s 625ms/step - accuracy: 0.9909 - loss: 0.0339 - val_accuracy: 0.9632 - val_loss: 0.1571
# Epoch 15/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9944 - loss: 0.0236
# Epoch 15: val_accuracy did not improve from 0.96319
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 542ms/step - accuracy: 0.9944 - loss: 0.0236 - val_accuracy: 0.9356 - val_loss: 0.2678
# Epoch 16/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.9935 - loss: 0.0140
# Epoch 16: val_accuracy did not improve from 0.96319
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 550ms/step - accuracy: 0.9935 - loss: 0.0140 - val_accuracy: 0.9555 - val_loss: 0.2054
# Epoch 17/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9914 - loss: 0.0321
# Epoch 17: val_accuracy did not improve from 0.96319
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 46s 555ms/step - accuracy: 0.9914 - loss: 0.0320 - val_accuracy: 0.9540 - val_loss: 0.2160
# Epoch 18/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.9893 - loss: 0.0386
# Epoch 18: val_accuracy did not improve from 0.96319
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 44s 541ms/step - accuracy: 0.9893 - loss: 0.0386 - val_accuracy: 0.9172 - val_loss: 0.2269
# Epoch 19/30
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.9869 - loss: 0.0462
# Epoch 19: val_accuracy did not improve from 0.96319
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 45s 553ms/step - accuracy: 0.9869 - loss: 0.0461 - val_accuracy: 0.9494 - val_loss: 0.2043
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
# Visualize some predictions
class_labels = {v:k for k,v in train_generator.class_indices.items()}
image_paths = []
for cls in classes:
    cls_dir = os.path.join(base_test_dir, cls)
    if os.path.exists(cls_dir):
        image_paths.extend([os.path.join(cls_dir, f) for f in os.listdir(cls_dir) if f.endswith(('.jpg', '.png'))])
random_samples = random.sample(image_paths, min(10, len(image_paths)))

plt.figure(figsize=(20,8))
for i, img_path in enumerate(random_samples):
    img = cv2.imread(img_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img_rgb, (224,224))
    img_exp = np.expand_dims(img_resized, axis=0) / 255.

    preds = model.predict(img_exp)
    pred_class = class_labels[np.argmax(preds)]

    plt.subplot(2,5,i+1)
    plt.imshow(img_rgb)
    plt.title(f"Predicted: {pred_class}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, recall_score


# Get true labels and predicted probabilities from test generator
test_steps = test_generator.samples // test_generator.batch_size
if test_generator.samples % test_generator.batch_size != 0:
    test_steps += 1

y_true = test_generator.classes
y_pred_probs = model.predict(test_generator, steps=test_steps, verbose=1)
y_pred = np.argmax(y_pred_probs, axis=1)

# Accuracy
accuracy = accuracy_score(y_true, y_pred)

# F1 Score (macro and per class)
f1_macro = f1_score(y_true, y_pred, average='macro')
f1_per_class = f1_score(y_true, y_pred, average=None)

# Sensitivity (Recall)
recall_macro = recall_score(y_true, y_pred, average='macro')
recall_per_class = recall_score(y_true, y_pred, average=None)

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

print("Accuracy:", accuracy)
print("Macro F1 Score:", f1_macro)
print("Per Class F1 Score:", f1_per_class)
print("Macro Sensitivity (Recall):", recall_macro)
print("Per Class Sensitivity (Recall):", recall_per_class)
print("Confusion Matrix:\n", cm)

# Optionally, display a classification report with precision, recall, f1 per class
print("\nClassification Report:\n", classification_report(y_true, y_pred, target_names=classes))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# Accuracy: 0.95
# Macro F1 Score: 0.9494949494949495
# Per Class F1 Score: [0.88888889 0.90909091 1.         1.        ]
# Macro Sensitivity (Recall): 0.95
# Per Class Sensitivity (Recall): [0.8 1.  1.  1. ]
# Confusion Matrix:
#  [[4 1 0 0]
#  [0 5 0 0]
#  [0 0 5 0]
#  [0 0 0 5]]
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#     glioma_tumor       1.00      0.80      0.89         5
# meningioma_tumor       0.83      1.00      0.91         5
#         no_tumor       1.00      1.00      1.00         5
#  pituitary_tumor       1.00      1.00      1.00         5
#
#         accuracy                           0.95        20
#        macro avg       0.96      0.95      0.95        20
#     weighted avg       0.96      0.95      0.95        20

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Prepare a DataFrame for boxplot visualization
data = []
for i, cls in enumerate(classes):
    for j in range(len(y_true)):
        data.append({
            'True Class': classes[y_true[j]],
            'Predicted Class': cls,
            'Predicted Probability': y_pred_probs[j][i]
        })

df = pd.DataFrame(data)

plt.figure(figsize=(14, 8))
sns.boxplot(x='Predicted Class', y='Predicted Probability', hue='True Class', data=df, palette='tab10')
plt.title('Boxplot of Predicted Probabilities grouped by True Class')
plt.xticks(rotation=45)
plt.legend(title='True Class', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

def plot_classification_report_extended(y_true, y_pred, classes, figsize=(12, 6)):
    report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

    # Prepare rows for per-class, macro avg, weighted avg
    rows = classes + ['macro avg', 'weighted avg']
    metrics = ['precision', 'recall', 'f1-score']
    data = []
    for row in rows:
        row_data = [report[row][metric] if metric in report[row] else 0 for metric in metrics]
        data.append(row_data)

    df = pd.DataFrame(data, index=rows, columns=metrics)

    # Colors inspired by research standards (Tableau 10 palette samples)
    colors = ['#1f77b4',  # muted blue
              '#ff7f0e',  # safety orange
              '#2ca02c']  # cooked asparagus green

    ax = df.plot(kind='bar', figsize=figsize, color=colors)
    ax.set_title('Classification Report: Per Class, Macro & Weighted Avg')
    ax.set_ylabel('Score')
    ax.set_ylim(0, 1.05)
    ax.set_xlabel('Classes')
    ax.set_xticks(np.arange(len(rows)))
    ax.set_xticklabels(rows, rotation=45)
    ax.legend(loc='lower right')
    plt.tight_layout()
    plt.show()

# Example usage:
plot_classification_report_extended(y_true, y_pred, classes)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.metrics import classification_report

def plot_classification_report(y_true, y_pred, classes, figsize=(8,6), cmap='Blues'):
    report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)
    # Remove accuracy and averages from the dict for plotting
    classes_metrics = {k: v for k, v in report.items() if k in classes}

    metrics = ['precision', 'recall', 'f1-score', 'support']
    values = np.array([[metrics_info[m] for m in metrics] for cls, metrics_info in classes_metrics.items()])
    # Plot support separately for better scale by normalizing or use separate axis if needed

    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(values[:, :-1], annot=True, fmt=".2f", cmap=cmap, cbar=True,
                yticklabels=classes, xticklabels=metrics[:-1], ax=ax)
    ax.set_title("Classification Report Metrics")
    plt.show()

# Use in your code after predictions like:
plot_classification_report(y_true, y_pred, classes)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

# Plot confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap=plt.cm.Blues)

# Rotate x-axis labels to 45 degrees with right alignment and anchored rotation
plt.xticks(rotation=45, ha='right', rotation_mode='anchor')

plt.title("Confusion Matrix")
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
import numpy as np

# Binarize the true labels for multiclass ROC (one-hot encoding)
y_true_bin = label_binarize(y_true, classes=range(len(classes)))
n_classes = y_true_bin.shape[1]

# Get prediction probabilities for each class
y_score = y_pred_probs

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_true_bin.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot all ROC curves
plt.figure(figsize=(10, 8))
colors = cycle(['aqua', 'darkorange', 'cornflowerblue', 'green'])  # Use research paper style colors

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'ROC curve of class {classes[i]} (area = {roc_auc[i]:0.2f})')

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.2f})'.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=3)

plt.plot([0, 1], [0, 1], 'k--', lw=2)  # Diagonal line for random guess
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Multiclass ROC Curves')
plt.legend(loc="lower right")
plt.show()
